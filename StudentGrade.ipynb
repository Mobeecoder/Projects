# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %%
data = pd.read_csv('https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Grades/Grades.csv')
data
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 0    CS-97001     B-     D+     C-         C     C-     D+      D     C-
# 1    CS-97002      A      D     D+         D     B-      C      D      A
# 2    CS-97003      A      B      A        B-     B+      A     B-     B+
# 3    CS-97004      D     C+     D+         D      D     A-     D+     C-
# 4    CS-97005     A-     A-     A-        B+      A      A     A-     B+
# ..        ...    ...    ...    ...       ...    ...    ...    ...    ...
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# ...

# %%
data.shape
# Out:
# (571, 43)

# %%
data.columns.tolist()
# Out:
# ['Seat No.',
#  'PH-121',
#  'HS-101',
#  'CY-105',
#  'HS-105/12',
#  'MT-111',
#  'CS-105',
#  'CS-106',
#  'EL-102',
#  'EE-119',
#  'ME-107',
#  'CS-107',
#  'HS-205/20',
#  'MT-222',
#  'EE-222',
#  'MT-224',
#  'CS-210',
#  'CS-211',
#  'CS-203',
#  'CS-214',
#  'EE-217',
#  'CS-212',
#  'CS-215',
#  'MT-331',
#  'EF-303',
#  'HS-304',
#  'CS-301',
#  'CS-302',
#  'TC-383',
#  'MT-442',
#  'EL-332',
#  'CS-318',
#  'CS-306',
#  'CS-312',
#  'CS-317',
#  'CS-403',
#  'CS-421',
#  'CS-406',
#  'CS-414',
#  'CS-419',
#  'CS-423',
#  'CS-412',
#  'CGPA']

# %%
data.isnull().sum()
# Out:
# Seat No.      0
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %%
mean_math_grade=data['CGPA'].mean()
mean_math_grade
# Out:
# 2.9548879159369528

# %%
sns.displot(data=data, x='CGPA', kde=True)

# %%
pd.get_dummies(data).corr()['CGPA'].sort_values()
# Out:
# MT-222_D      -0.402790
# PH-121_D      -0.390818
# HS-105/12_D   -0.373052
# CS-215_D      -0.372241
# ME-107_D      -0.359588
#                  ...
# MT-224_A       0.438979
# CS-306_A       0.450589
# CS-302_A       0.464615
# CS-210_A       0.486896
# CGPA           1.000000
# Name: CGPA, Length: 1098, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(pd.get_dummies(data).corr())
# Out:
# <Axes: >
